# %% [markdown]
# ### Analysis_4
# Find out which tags are used to describe and represent each genre, show result using word cloud <br>
# Use grenre Drama, Comedy and Sci-Fi as examples.<br>
# Steps:
# 1. For each movie, find out the genre(s) and corresponding tag word.
# 2. Collect genres and their tag words in dataframe

# %%
import os
import pandas as pd
import numpy as np
from pandas import DataFrame as df
from datetime import datetime
import time
from wordcloud import WordCloud, STOPWORDS
from scipy.misc import imread
import matplotlib.pyplot as plt

# %%
rootdir = os.path.expanduser('~')+'/final/data/ml-20m-dataset'

# %%
movies = pd.read_csv(rootdir+'/movies.csv')
tags = pd.read_csv(rootdir+'/tags.csv')

# %%
stopwords = set(STOPWORDS)

# %% [markdown]
# **Get all movies' genres**

# %%
genres_list = []

# %%
def get_genre(genres):
    [genres_list.append(x) for x in genres.split("|")]

# %%
movies['genres'].apply(get_genre).head(2)
# Out:
# 0    None
# 1    None
# Name: genres, dtype: object

# %%
len(set(genres_list))
# Out:
# 20

# %%
movies_1 = movies.copy()

# %%
for x in set(genres_list):
    movies_1[x] = movies_1['genres'].apply(lambda y: x in y)

# %%
movies_1.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres Comedy Documentary Animation  \
# 0  Adventure|Animation|Children|Comedy|Fantasy   True       False      True
# 1                   Adventure|Children|Fantasy  False       False     False
# 2                               Comedy|Romance   True       False     False
# 3                         Comedy|Drama|Romance   True       False     False
# 4                                       Comedy   True       False     False
#
#    Drama Fantasy Mystery Children   ...   Film-Noir Romance Sci-Fi    War  \
# 0  False    True   False     True   ...       False   False  False  False
# ...

# %%
tags.ix[1]
# Out:
# userId               65
# movieId             208
# tag           dark hero
# timestamp    1368150078
# Name: 1, dtype: object

# %%
tags[['movieId','tag']].head()
# Out:
#    movieId            tag
# 0     4141    Mark Waters
# 1      208      dark hero
# 2      353      dark hero
# 3      521  noir thriller
# 4      592      dark hero

# %%
df_drama_tags = movies_1[movies_1['Drama']==True][['movieId']].merge(tags[['movieId','tag']], on='movieId')
df_drama_tags.head()
# Out:
#    movieId          tag
# 0        4  chick flick
# 1        4      revenge
# 2        4   characters
# 3        4  chick flick
# 4        4   characters

# %%
cut_text = " ".join(str(e) for e in df_drama_tags['tag'].values.tolist()) 
color_mask = imread(os.path.expanduser('~')+'/final/data/alice.jpg') 
cloud = WordCloud(background_color='white',mask=color_mask,max_words=2000,max_font_size=40,stopwords=stopwords)
cloud.generate(cut_text) 
cloud.to_file(os.path.expanduser('~')+'/final/analysis/drama_wordcloud.png')

# %%
plt.imshow(cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_comedy_tags = movies_1[movies_1['Comedy']==True][['movieId']].merge(tags[['movieId','tag']], on='movieId')
df_comedy_tags.head()
# Out:
#    movieId                                     tag
# 0        1                                 Watched
# 1        1                      computer animation
# 2        1                 Disney animated feature
# 3        1                         Pixar animation
# 4        1  T̩a Leoni does not star in this movie

# %%
cut_text = " ".join(str(e) for e in df_comedy_tags['tag'].values.tolist()) 
color_mask = imread(os.path.expanduser('~')+'/final/data/bird.png') 
cloud = WordCloud(background_color='white',mask=color_mask,max_words=2000,max_font_size=40,stopwords=stopwords)
cloud.generate(cut_text) 
cloud.to_file(os.path.expanduser('~')+'/final/analysis/comedy_wordcloud.png')

# %%
plt.imshow(cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_SciFi_tags = movies_1[movies_1['Sci-Fi']==True][['movieId']].merge(tags[['movieId','tag']], on='movieId')
df_SciFi_tags.head()
# Out:
#    movieId             tag
# 0       24          albino
# 1       24  special powers
# 2       24         earnest
# 3       24         elegiac
# 4       24        poignant

# %%
cut_text = " ".join(str(e) for e in df_SciFi_tags['tag'].values.tolist()) 
color_mask = imread(os.path.expanduser('~')+'/final/data/like.png') 
cloud = WordCloud(background_color='white',mask=color_mask,max_words=2000,max_font_size=40,stopwords=stopwords)
cloud.generate(cut_text) 
cloud.to_file(os.path.expanduser('~')+'/final/analysis/SciFi_wordcloud.png')

# %%
plt.imshow(cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
